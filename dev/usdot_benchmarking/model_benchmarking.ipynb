# %%
from jetfuelburn import ureg
from jetfuelburn.reducedorder import sacchi_etal
from jetfuelburn.reducedorder import yanto_etal
from jetfuelburn.reducedorder import montlaur_etal
from jetfuelburn.reducedorder import seymour_etal
from jetfuelburn.reducedorder import aim2015
from jetfuelburn.reducedorder import eea_emission_inventory_2009
from jetfuelburn.reducedorder import lee_etal
from jetfuelburn.reducedorder import myclimate

# %%
fuel_aim = aim2015.calculate_fuel_consumption(
    acft_size_class=5,
    D_climb=300 * ureg.km,
    D_cruise=(1594 - 300 - 200) * ureg.km,
    D_descent=200 * ureg.km,
    PL=128 * 100 * ureg.kg,
)

# %%
fuel_sacchi = sacchi_etal.calculate_fuel_consumption(
    year=2024,
    pax_max=180,
    pax=128,
    R=1594 * ureg.km,
)

# %%
fuel_yanto = yanto_etal.calculate_fuel_consumption(
    acft="A320",
    R=1594 * ureg.km,
    PL=128 * 100 * ureg.kg,
)

# %%
fuel_montlaur = montlaur_etal.calculate_fuel_consumption(
    distance=1594 * ureg.km,
    available_seats=180,
)

total_fuel_montlaur = 180 * fuel_montlaur

# %%
fuel_seymour = seymour_etal.calculate_fuel_consumption(
    acft="A320",
    R=1594 * ureg.km,
)

# %%
fuel_eea = eea_emission_inventory_2009.calculate_fuel_consumption(
    acft="A320", R=1594 * ureg.km
)

# %%
fuel_myclimate = myclimate.calculate_fuel_consumption(
    acft="A320",
    x=1594 * ureg.km,
)
